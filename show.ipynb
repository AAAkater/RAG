# %%
from src.Vectordb import vecdb
from src.LLM import LLM_model
from src.ShowAnswer import show

# %%
db = vecdb.retriever(vecdb_path="./database/")
llm = LLM_model(db_retriever=db)

# %%
question = "traffic light"

# %%
result = llm.invoke(question)
show(LLM_answer=result)
# Out:
# query:give me some information about the traffic light
#
# result:Traffic lights are signaling devices positioned at road intersections, pedestrian crossings, and other locations to control the flow of traffic. They typically consist of three colored lights: red, yellow (or amber), and green. Red means stop, yellow indicates caution, and green signals to proceed. In addition to the standard lights, traffic lights may also have arrows to indicate specific directions for vehicles to turn. Pedestrian crossing signals are often included to indicate when it is safe for pedestrians to cross the road. Traffic lights play a crucial role in regulating traffic flow, improving road safety, and reducing the risk of accidents.
