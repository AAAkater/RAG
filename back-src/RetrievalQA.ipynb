# %%
from src.LLM.Llama3 import Llama3
from ShowAnswer import show
from src.Storage.Milvus import Milvus

# %%
llm = Llama3(db_retriever=Milvus().as_retriever)

# %%
question = "apple fruit"

# %%
result = llm.invoke(question)
show(result)
# Out:
# query:give me some images information about the apple fruit
#
# result:The images provided showcase various displays of fruits, including apples. In the images, apples are predominantly red and green in color, and they are arranged in visually appealing manners alongside other fruits like oranges, lemons, grapes, and more. The apples are often shown as part of a vibrant assortment of fruits in baskets, bowls, or fruit stands, highlighting their colorful and healthy nature. The images present apples in different contexts, such as being cut open to reveal their juicy interiors or neatly arranged in displays at grocery stores.
